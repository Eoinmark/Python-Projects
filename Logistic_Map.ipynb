# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Initialize seed and growth parameter, r
N = 50 #number of iterations
x = 0.2+np.zeros(N) #for {xn}
x_prime = 0.200001+np.zeros(N)  #seed 1
x_diff = np.zeros(N)            #seed 2
r = 2


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.plot(x, 'r', label= '$x_0 = 0.2 $')
plt.plot(x_prime, '--b', label='$x_0 = 0.200001$')
plt.title('Logistic Map, r=2')
plt.xlabel('N')
plt.ylabel('x')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 50 #number of iterations
x = 0.2+np.zeros(N) #for {xn}
x_prime = 0.200001+np.zeros(N)
x_diff = np.zeros(N)
r = 2


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.plot(x_diff)
plt.ylabel("$ x_n-x' $")
plt.xlabel('n')
plt.title("$|x_n - x'| \hspace{1} vs \hspace{1} n$")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 50 #number of iterations
x = 0.2+np.zeros(N) #for {xn}
x_prime = 0.200001+np.zeros(N)
x_diff = np.zeros(N)
r = 3.4


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.xlabel('N')
plt.ylabel('x')
plt.plot(x, 'r', label= '$x_0 = 0.2 $')
plt.plot(x_prime, '--b', label='$x_0 = 0.200001$')
plt.title('Logistic Map, r=3.4')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 50#number of iterations
x = 0.2+np.zeros(N) #for {xn}
x_prime = 0.200001+np.zeros(N)
x_diff = np.zeros(N)
r = 3.4


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.plot(x_diff)
plt.ylabel("$ x_n-x' $")
plt.xlabel('n')
plt.title("$|x_n - x'| \hspace{1} vs \hspace{1} n$")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 60 #number of iterations
x = 0.2+np.zeros(N) #for {xn}
x_prime = 0.200001+np.zeros(N)
x_diff = np.zeros(N)
r = 3.72


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.xlabel('N')
plt.ylabel('x')
plt.plot(x, 'r', label= '$x_0 = 0.2 $')
plt.plot(x_prime, '--b', label="$x'_0 = 0.200001$")
plt.title('Logistic Map, r=3.72')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 50#number of iterations
x = 0.2+np.zeros(N) #for {xn} 
x_prime = 0.200001+np.zeros(N)
x_diff = np.zeros(N)
r = 3.72


#Calculate for terms using logistic map equation
for n in range(N-1):
    x[n+1] = r*x[n]*(1-x[n])
    x_prime[n+1] = r*x_prime[n]*(1-x_prime[n])
    x_diff = abs(x - x_prime)
    
plt.figure()
plt.plot(x_diff)
plt.title("$|x_n - x'| \hspace{1} vs \hspace{1} n$")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Initialize seed and growth parameter, r
N = 12 #number of iterations
br = 4.0
dr = 0
k = 20
n = 0

#Calculate for terms using logistic map equation
for t in range(N-1):
    print("n is,",n)
    print("for iteration,",t)
    n[t+1] = (br - dr)*(n[t] - ((n[t]**2)/k))
# Out:
# n is, 0
# for iteration, 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 print("n is,",n)
#      11 print("for iteration,",t)
# ---> 12 n[t+1] = (br - dr)*(n[t] - ((n[t]**2)/k))
#
# TypeError: 'int' object is not subscriptable
